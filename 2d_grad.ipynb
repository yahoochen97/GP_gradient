# %% [markdown]
# #### Gradient inference with functional observations in gpytorch (2-D example)

# %% [markdown]
# In this notebook, we demonstrate the inference of gradient (marginal effect) from functional observations in one simple 2-dimensional example, training an RBF kernel Gaussian process with automatic relevance determination (ARD). Our model also includes two-way fixed effects.

# %%
# LOAD PACKAGES
import torch
import gpytorch
from matplotlib import pyplot as plt
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.means import LinearMean
from gpytorch.kernels import ScaleKernel, RBFKernel
from gpytorch.models.exact_prediction_strategies import prediction_strategy
from gpytorch.means.mean import Mean
from gpytorch.kernels.kernel import Kernel
from gpytorch.lazy import InterpolatedLazyTensor
from gpytorch.utils.broadcasting import _mul_broadcast_shape

# %% [markdown]
# Set up data n = 500, D = 2, T = 1
#
# $x_{it}\in \mathbb{R}^D$
#
# $y_{it} = \sum\limits_{d=1}^D \sin(x_{it}*d)/d$ + a_i + b_t + \varepsilon
#
# $a_i\sim\mathbb{N}(0,1)$
#
# $b_t\sim\mathbb{N}(0,1)$
#
# $\varepsilon\sim\mathbb{N}(0,0.1^2)$

# %%
# define data
D = 2
n = 50
T = 10
torch.random.manual_seed(12345)
noise_sd = 0.1
soboleng = torch.quasirandom.SobolEngine(dimension=D)
train_x = 4*soboleng.draw(n*T)-2
train_i = torch.zeros((n*T,1))
train_t = torch.zeros((n*T,1))
train_y = torch.randn(n*T) * noise_sd

i_effects = torch.randn(n)
t_effects = torch.randn(T)

ARD_lss = 1 + torch.arange(D)

for i in range(n):
    for t in range(T):
        train_i[t+i*T,] = i
        train_t[t+i*T,] = t
        for k in range(D):
            train_y[t+i*T,] += torch.sin(train_x[t+i*T,k]*ARD_lss[k])/ARD_lss[k]
        train_y[t+i*T,] += i_effects[i] + t_effects[t]

# %% [markdown]
# define a constant mean function and an indicator kernel for 2FE

# %%
class ConstantVectorMean(Mean):
    def __init__(self, d=1, prior=None, batch_shape=torch.Size(), **kwargs):
        super(ConstantVectorMean, self).__init__()
        self.batch_shape = batch_shape
        self.register_parameter(name="constantvector", parameter=torch.nn.Parameter(torch.zeros(*batch_shape, d)))
        if prior is not None:
            self.register_prior("mean_prior", prior, "constantvector")

    def forward(self, input):
        # results = torch.zeros(input.shape)
        # for i in range(input.shape[0]):
        #     results[i] = self.constantvector[input[i].item()]
        return self.constantvector[input.int().reshape((-1,)).tolist()]

class myIndicatorKernel(Kernel):
    r"""
    A kernel for discrete indices. Kernel is defined by a lookup table.

    """

    def __init__(self, num_tasks, **kwargs):
        super().__init__(**kwargs)

        self.num_tasks = num_tasks

    def covar_matrix(self):
        res = torch.eye(self.num_tasks)
        return res

    def forward(self, i1, i2, **params):
        covar_matrix = self.covar_matrix()
        batch_shape = _mul_broadcast_shape(i1.shape[:-2], self.batch_shape)
        index1_shape = batch_shape + i1.shape[-2:]
        index2_shape = batch_shape + i2.shape[-2:]

        res = InterpolatedLazyTensor(
            base_lazy_tensor=covar_matrix,
            left_interp_indices=i1.long().expand(index1_shape),
            right_interp_indices=i2.long().expand(index2_shape),
        )
        return res

# %% [markdown]
# define a GP model with linear mean and sqrexp ARD kernel with gradient

# %%
class DerivativeExactGP(gpytorch.models.ExactGP):
    """Derivative of the ExactGPModel w.r.t. the test points x.
    Since differentiation is a linear operator this is again a Gaussian process.
    Attributes:
        train_x: (N x D) The training features X.
        train_i: (N x 1) The training unit index i.
        train_t: (N x 1) The training time index t.
        train_y: (N x 1) The training targets y.
        likelihood: gpytorch likelihood.
    """

    def __init__(
        self,
        train_x=None,
        train_i=None,
        train_t=None,
        train_y=None,
        likelihood=None
    ):
        """Inits GP model with data and a Gaussian likelihood."""
        if likelihood is None:
            likelihood = GaussianLikelihood()
        if train_y is not None:
            train_y = train_y.squeeze(-1)
        super(DerivativeExactGP, self).__init__((train_x,train_i,train_t), train_y, likelihood)

        self.D = train_x.shape[1]
        self.n = train_i.max().long().item()+1
        self.T = train_t.max().long().item()+1
        self.N = train_x.shape[0]
        # self.train_inputs = (train_x, train_i, train_t)
        # self.train_targets = train_y

        # time and unit fixed effects
        self.i_mean_module =  ConstantVectorMean(d=self.n)
        self.t_mean_module = ConstantVectorMean(d=self.T)
        self.i_covar_module = ScaleKernel(myIndicatorKernel(self.n))
        self.t_covar_module = ScaleKernel(myIndicatorKernel(self.T))

        # covariate effect with linear mean and sqrexp ARD kernel
        self.mean_module = LinearMean(input_size=self.D)
        self.covar_module = ScaleKernel(RBFKernel(ard_num_dims=self.D))

    def forward(self, x, i , t):
        """Compute the prior latent distribution on a given input.
        Typically, this will involve a mean and kernel function. The result must be a
        MultivariateNormal. Calling this model will return the posterior of the latent
        Gaussian process when conditioned on the training data. The output will be a
        MultivariateNormal.
        Args:
            x: (n x D) The test points.
            i: (n x 1) The test unit index.
            t: (n x 1) The test time index.
        Returns:
            A MultivariateNormal.
        """
        mean_x = self.mean_module(x) + self.i_mean_module(i) + self.t_mean_module(t)
        covar_x = self.covar_module(x) + self.i_covar_module(i) + self.t_covar_module(t)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

    def get_L_lower(self):
        """Get Cholesky decomposition L, where L is a lower triangular matrix.
        Returns:
            Cholesky decomposition L.
        """
        return (
            self.prediction_strategy.lik_train_train_covar.root_decomposition()
            .root.evaluate()
            .detach()
        )

    def get_KXX_inv(self):
        """Get the inverse matrix of K(X,X).
        Returns:
            The inverse of K(X,X).
        """
        L_inv_upper = self.prediction_strategy.covar_cache.detach()
        return L_inv_upper @ L_inv_upper.transpose(0, 1)

    def get_KXX_inv_old(self):
        """Get the inverse matrix of K(X,X).
        Not as efficient as get_KXX_inv.
        Returns:
            The inverse of K(X,X).
        """
        X = self.train_inputs[0]
        sigma_n = self.likelihood.noise_covar.noise.detach()
        KXX = torch.eye(X.shape[0]) * sigma_n + self.covar_module(X).evaluate()
        return torch.inverse(KXX)

    def _get_KxX_dx(self, x):
        """Computes the analytic derivative of the kernel K(x,X) w.r.t. x.
        Args:
            x: (n x D) Test points.
        Returns:
            (n x D) The derivative of K(x,X) w.r.t. x.
        """
        X = self.train_inputs[0]
        n = x.shape[0]
        K_xX = self.covar_module(x, X).evaluate()
        lengthscale = self.covar_module.base_kernel.lengthscale.detach()
        return (
            -torch.eye(self.D, device=x.device)
            / lengthscale ** 2
            @ (
                (x.view(n, 1, self.D) - X.view(1, self.N, self.D))
                * K_xX.view(n, self.N, 1)
            ).transpose(1, 2)
        )

    def _get_Kxx_dx2(self):
        """Computes the analytic second derivative of the kernel K(x,x) w.r.t. x.
        Args:
            x: (n x D) Test points.
        Returns:
            (n x D x D) The second derivative of K(x,x) w.r.t. x.
        """
        lengthscale = self.covar_module.base_kernel.lengthscale.detach()
        sigma_f = self.covar_module.outputscale.detach()
        return (
            torch.eye(self.D, device=lengthscale.device) / lengthscale ** 2
        ) * sigma_f

    def _get_mu_dx(self, x):
        """Get the derivative of mu(x).
        Returns:
            The gradient of linear mu(x) wrt x.
        """
        return self.mean_module.weights.expand(x.t().shape).t() # x.grad.data.reshape((-1,self.D))

    def posterior_derivative(self, x):
        """Computes the posterior of the derivative of the GP w.r.t. the given test
        points x.
        Args:
            x: (n x D) Test points.
        Returns:
            A GPyTorchPosterior.
        """
        mu_x_dx = self._get_mu_dx(x)

        with torch.no_grad():
            if self.prediction_strategy is None:
                train_output = super().__call__(self.train_inputs)
                # Create the prediction strategy for
                self.prediction_strategy = prediction_strategy(
                    train_inputs=self.train_inputs,
                    train_prior_dist=train_output,
                    train_labels=self.train_targets,
                    likelihood=self.likelihood,
                )

            K_xX_dx = self._get_KxX_dx(x)
            mu_prior = self.mean_module(self.train_inputs[0]) + self.i_mean_module(self.train_inputs[1]) + self.t_mean_module(self.train_inputs[2])
            mean_d = mu_x_dx + K_xX_dx @ self.get_KXX_inv() @ (self.train_targets - mu_prior)
            variance_d = (
                self._get_Kxx_dx2() - K_xX_dx @ self.get_KXX_inv() @ K_xX_dx.transpose(1, 2)
            )
            variance_d = variance_d.clamp_min(1e-8)

        return mean_d, variance_d

# %% [markdown]
# define likelihood and derivativeExactGP model

# %%
likelihood = GaussianLikelihood()
model = DerivativeExactGP(train_x,train_i,train_t, train_y, likelihood)
# model.covar_module.register_prior("outputscale_prior", gpytorch.priors.UniformPrior(0.1, 3.0),"outputscale")
# model.covar_module.register_prior("lengthscale_prior", gpytorch.priors.UniformPrior(0.1, 3.0), "lengthscale")

# %% [markdown]
# learn hyperparameter by minimizing the negative log likelihood using ADAM optimizer

# %%
# train
model.train()
likelihood.train()

# Use the adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)  # Includes GaussianLikelihood parameters

# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

training_iter = 50
for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(train_x,train_i,train_t)
    # Calc loss and backprop gradients
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f  slope: %.3f   lengthscale1: %.3f  lengthscale2: %.3f    outputscale: %.3f  noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.mean_module.weights[0].item(),
        model.covar_module.base_kernel.lengthscale[0,0].item(),
        model.covar_module.base_kernel.lengthscale[0,1].item(),
        model.covar_module.outputscale.item(),
        likelihood.noise.item()
    ))
    optimizer.step()
# Out:
# Iter 1/50 - Loss: 0.160  slope: 0.437   lengthscale1: 1.837  lengthscale2: 1.506    outputscale: 1.268  noise: 0.123
# Iter 2/50 - Loss: 0.115  slope: 0.337   lengthscale1: 1.922  lengthscale2: 1.429    outputscale: 1.197  noise: 0.112
# Iter 3/50 - Loss: 0.071  slope: 0.238   lengthscale1: 1.921  lengthscale2: 1.395    outputscale: 1.128  noise: 0.102
# Iter 4/50 - Loss: 0.030  slope: 0.144   lengthscale1: 1.901  lengthscale2: 1.387    outputscale: 1.061  noise: 0.092
# Iter 5/50 - Loss: -0.010  slope: 0.066   lengthscale1: 1.897  lengthscale2: 1.377    outputscale: 0.997  noise: 0.084
# Iter 6/50 - Loss: -0.051  slope: 0.017   lengthscale1: 1.915  lengthscale2: 1.354    outputscale: 0.936  noise: 0.076
# Iter 7/50 - Loss: -0.092  slope: -0.001   lengthscale1: 1.934  lengthscale2: 1.320    outputscale: 0.882  noise: 0.069
# Iter 8/50 - Loss: -0.132  slope: 0.007   lengthscale1: 1.930  lengthscale2: 1.284    outputscale: 0.837  noise: 0.063
# Iter 9/50 - Loss: -0.171  slope: 0.034   lengthscale1: 1.902  lengthscale2: 1.260    outputscale: 0.798  noise: 0.057
# Iter 10/50 - Loss: -0.210  slope: 0.072   lengthscale1: 1.860  lengthscale2: 1.253    outputscale: 0.763  noise: 0.052
# Iter 11/50 - Loss: -0.248  slope: 0.118   lengthscale1: 1.814  lengthscale2: 1.256    outputscale: 0.728  noise: 0.047
# Iter 12/50 - Loss: -0.284  slope: 0.166   lengthscale1: 1.774  lengthscale2: 1.258    outputscale: 0.694  noise: 0.043
# Iter 13/50 - Loss: -0.320  slope: 0.213   lengthscale1: 1.746  lengthscale2: 1.249    outputscale: 0.659  noise: 0.039
# Iter 14/50 - Loss: -0.355  slope: 0.250   lengthscale1: 1.730  lengthscale2: 1.230    outputscale: 0.624  noise: 0.035
# Iter 15/50 - Loss: -0.389  slope: 0.273   lengthscale1: 1.717  lengthscale2: 1.208    outputscale: 0.590  noise: 0.032
# Iter 16/50 - Loss: -0.421  slope: 0.279   lengthscale1: 1.700  lengthscale2: 1.190    outputscale: 0.556  noise: 0.029
# Iter 17/50 - Loss: -0.451  slope: 0.270   lengthscale1: 1.680  lengthscale2: 1.180    outputscale: 0.523  noise: 0.027
# Iter 18/50 - Loss: -0.480  slope: 0.250   lengthscale1: 1.661  lengthscale2: 1.174    outputscale: 0.492  noise: 0.024
# Iter 19/50 - Loss: -0.507  slope: 0.225   lengthscale1: 1.652  lengthscale2: 1.167    outputscale: 0.464  noise: 0.022
# Iter 20/50 - Loss: -0.532  slope: 0.201   lengthscale1: 1.653  lengthscale2: 1.155    outputscale: 0.440  noise: 0.020
# Iter 21/50 - Loss: -0.554  slope: 0.183   lengthscale1: 1.660  lengthscale2: 1.143    outputscale: 0.423  noise: 0.019
# Iter 22/50 - Loss: -0.575  slope: 0.175   lengthscale1: 1.664  lengthscale2: 1.137    outputscale: 0.412  noise: 0.017
# Iter 23/50 - Loss: -0.593  slope: 0.178   lengthscale1: 1.660  lengthscale2: 1.137    outputscale: 0.409  noise: 0.016
# Iter 24/50 - Loss: -0.610  slope: 0.189   lengthscale1: 1.650  lengthscale2: 1.139    outputscale: 0.412  noise: 0.014
# Iter 25/50 - Loss: -0.624  slope: 0.206   lengthscale1: 1.642  lengthscale2: 1.141    outputscale: 0.420  noise: 0.013
# Iter 26/50 - Loss: -0.635  slope: 0.222   lengthscale1: 1.641  lengthscale2: 1.140    outputscale: 0.430  noise: 0.012
# Iter 27/50 - Loss: -0.645  slope: 0.233   lengthscale1: 1.649  lengthscale2: 1.141    outputscale: 0.441  noise: 0.012
# Iter 28/50 - Loss: -0.652  slope: 0.235   lengthscale1: 1.662  lengthscale2: 1.146    outputscale: 0.453  noise: 0.011
# Iter 29/50 - Loss: -0.658  slope: 0.227   lengthscale1: 1.674  lengthscale2: 1.153    outputscale: 0.465  noise: 0.010
# Iter 30/50 - Loss: -0.663  slope: 0.210   lengthscale1: 1.683  lengthscale2: 1.159    outputscale: 0.477  noise: 0.010
# Iter 31/50 - Loss: -0.666  slope: 0.189   lengthscale1: 1.692  lengthscale2: 1.159    outputscale: 0.491  noise: 0.009
# Iter 32/50 - Loss: -0.669  slope: 0.168   lengthscale1: 1.703  lengthscale2: 1.156    outputscale: 0.504  noise: 0.009
# Iter 33/50 - Loss: -0.671  slope: 0.151   lengthscale1: 1.717  lengthscale2: 1.157    outputscale: 0.518  noise: 0.008
# Iter 34/50 - Loss: -0.674  slope: 0.141   lengthscale1: 1.732  lengthscale2: 1.163    outputscale: 0.530  noise: 0.008
# Iter 35/50 - Loss: -0.677  slope: 0.138   lengthscale1: 1.741  lengthscale2: 1.172    outputscale: 0.543  noise: 0.008
# Iter 36/50 - Loss: -0.680  slope: 0.141   lengthscale1: 1.744  lengthscale2: 1.177    outputscale: 0.556  noise: 0.008
# Iter 37/50 - Loss: -0.684  slope: 0.149   lengthscale1: 1.743  lengthscale2: 1.176    outputscale: 0.569  noise: 0.008
# Iter 38/50 - Loss: -0.688  slope: 0.158   lengthscale1: 1.742  lengthscale2: 1.174    outputscale: 0.580  noise: 0.008
# Iter 39/50 - Loss: -0.693  slope: 0.167   lengthscale1: 1.745  lengthscale2: 1.177    outputscale: 0.587  noise: 0.008
# Iter 40/50 - Loss: -0.698  slope: 0.173   lengthscale1: 1.747  lengthscale2: 1.183    outputscale: 0.591  noise: 0.008
# Iter 41/50 - Loss: -0.704  slope: 0.175   lengthscale1: 1.749  lengthscale2: 1.186    outputscale: 0.592  noise: 0.008
# Iter 42/50 - Loss: -0.710  slope: 0.172   lengthscale1: 1.749  lengthscale2: 1.184    outputscale: 0.591  noise: 0.008
# Iter 43/50 - Loss: -0.717  slope: 0.166   lengthscale1: 1.748  lengthscale2: 1.181    outputscale: 0.587  noise: 0.008
# Iter 44/50 - Loss: -0.723  slope: 0.158   lengthscale1: 1.748  lengthscale2: 1.181    outputscale: 0.581  noise: 0.008
# Iter 45/50 - Loss: -0.728  slope: 0.152   lengthscale1: 1.748  lengthscale2: 1.182    outputscale: 0.574  noise: 0.009
# Iter 46/50 - Loss: -0.734  slope: 0.148   lengthscale1: 1.749  lengthscale2: 1.181    outputscale: 0.566  noise: 0.009
# Iter 47/50 - Loss: -0.739  slope: 0.147   lengthscale1: 1.746  lengthscale2: 1.179    outputscale: 0.558  noise: 0.009
# Iter 48/50 - Loss: -0.743  slope: 0.152   lengthscale1: 1.739  lengthscale2: 1.177    outputscale: 0.552  noise: 0.009
# Iter 49/50 - Loss: -0.747  slope: 0.159   lengthscale1: 1.734  lengthscale2: 1.177    outputscale: 0.546  noise: 0.009
# Iter 50/50 - Loss: -0.751  slope: 0.167   lengthscale1: 1.730  lengthscale2: 1.177    outputscale: 0.540  noise: 0.010

# %% [markdown]
# plot partial gradients

# %%
model.eval()
likelihood.eval()

with torch.no_grad(), gpytorch.settings.fast_pred_var():
    observed_pred = likelihood(model(train_x, train_i, train_t))

with torch.no_grad():
    mean_d, variance_d = model.posterior_derivative(train_x)
    variance_d = torch.diagonal(variance_d, dim1=1,dim2=2)
    
_, ax = plt.subplots(nrows=2,ncols=1,figsize=(6, 8))

for k in range(D):
    sorted, idx = torch.sort(train_x[:,k])
    ax[k].plot(sorted.numpy(), torch.cos(sorted*ARD_lss[k]).numpy(), '--k',label='true grad')
    ax[k].errorbar(sorted.numpy(), mean_d[idx,k].numpy(), yerr=2*variance_d[idx,k].numpy()**0.5,\
            marker='s', mfc='red', mec='black', ms=2, mew=2,label='estimated grad')

    ax[k].legend()
    ax[k].set_title('Estimated partial gradient of x' + str(k))

plt.show()
